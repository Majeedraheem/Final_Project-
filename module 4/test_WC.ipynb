# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample DataFrame
data = {'text': ['Python is amazing', 'I love coding in Python', 'Data science is great', 'Word clouds are fun']}
df = pd.DataFrame(data)

# Combine all text in the specified column into a single string
text = ' '.join(df['text'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axis
plt.show()

# %%
df
# Out:
#                       text
# 0        Python is amazing
# 1  I love coding in Python
# 2    Data science is great
# 3      Word clouds are fun
